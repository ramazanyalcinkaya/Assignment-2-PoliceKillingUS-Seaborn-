# %% [markdown]
# # WITH SEABORN

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# INSTRUCTIONS
# 1. Box and Swarm Plots in kill data
# 1. Most dangerous cities
# 1. Most dangerous states
# 1. Having mental ilness or not for killed people
# 1. Threat types
# 1. Flee types
# <br>

# %% [markdown]
# read data
#
# if didn't work you can use this parameters: encoding="windows-1252"

# %%
kill = pd.read_csv('PoliceKillingsUS.csv', encoding="windows-1252")

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
kill.shape
# Out:
# (2535, 14)

# %%
# Out:
# (2535, 14)

# %%
kill =kill.dropna()

# %%
kill.shape
# Out:
# (2254, 14)

# %%
# Out:
# (2254, 14)

# %% [markdown]
# ## 1a: Box plot of age in both genders separeted by manner of death.

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
kill.manner_of_death.unique()
# Out:
# array(['shot', 'shot and Tasered'], dtype=object)

# %% [markdown]
# **INSTRUCTION: Demonstrate the Qurtiles of age in both genders separeted by manner of death.**

# %%
sns.boxplot(x=kill['gender'], y=kill['age'], hue= kill['manner_of_death']);

# %%
# with seaborn

# %% [markdown]
# ## 1b: Swarm Plot

# %% [markdown]
# **INSTRUCTION: Demonstrate the age in both genders separeted by manner of death by a swarm plot.**

# %%
sns.swarmplot(x=kill['gender'], y=kill['age'], hue=kill['manner_of_death']);

# %%
# with seaborn

# %% [markdown]
# ## 2: Plot 12 most dangerous cities

# %%
x = kill['city'].value_counts().sort_values(ascending=False)[:13]
x
# Out:
# Los Angeles      35
# Phoenix          28
# Houston          24
# Chicago          22
# Austin           18
# Las Vegas        17
# Columbus         16
# San Antonio      15
# Miami            15
# Indianapolis     14
# St. Louis        14
# Bakersfield      13
# Oklahoma City    13
# Name: city, dtype: int64

# %%
# Out:
# Los Angeles      35
# Phoenix          28
# Houston          24
# Chicago          22
# Austin           18
# Las Vegas        17
# Columbus         16
# San Antonio      15
# Miami            15
# Indianapolis     14
# St. Louis        14
# Oklahoma City    13
# Name: city, dtype: int64

# %%
a=x.index
b=x.values

# %%
fig, ax = plt.subplots(figsize=(10, 8))

sns.barplot(x=a, y=b, data=kill)
ax.set_xticklabels(a, rotation=45)d
plt.tight_layout()

# %%
# with seaborn barplot

# %%
# with seaborn countplot

# %% [markdown]
# ## 3: Plot 20 most dangerous states

# %%
kill['state'].value_counts().sort_values(ascending=False)[:21]
# Out:
# CA    366
# TX    200
# FL    136
# AZ    105
# OH     70
# NC     66
# OK     65
# CO     63
# GA     61
# MO     58
# TN     56
# IL     56
# WA     51
# LA     47
# AL     45
# PA     45
# NY     43
# VA     43
# WI     42
# NM     41
# SC     41
# Name: state, dtype: int64

# %%
# Out:
# CA    366
# TX    200
# FL    136
# AZ    105
# OH     70
# NC     66
# OK     65
# CO     63
# GA     61
# MO     58
# TN     56
# IL     56
# WA     51
# LA     47
# PA     45
# AL     45
# NY     43
# VA     43
# WI     42
# NM     41
# Name: state, dtype: int64

# %%
c=kill['state'].value_counts().sort_values(ascending=False)[:21]

# %%
d=c.index
e=c.values

# %%
fig, ax = plt.subplots(figsize=(10, 8))

sns.barplot(x=d, y=e, data=kill)
ax.set_xticklabels(d, rotation=45)
plt.tight_layout()

# %%
# with seaborn barplot

# %%
fig, ax = plt.subplots(figsize=(10, 8))

sns.countplot(x='state', order=d,data=kill)
ax.set_xticklabels(d, rotation=45)
plt.tight_layout()

# %%
# with seaborn countplot

# %% [markdown]
# ## 4: Plot Having mental ilness or not for killed people

# %%
kill.signs_of_mental_illness.value_counts()
# Out:
# False    1681
# True      573
# Name: signs_of_mental_illness, dtype: int64

# %%
# Out:
# False    1681
# True      573
# Name: signs_of_mental_illness, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(4, 4))
sns.countplot(x='signs_of_mental_illness', data=kill);

# %%
# with seaborn

# %% [markdown]
# ## 5: Plot number of Threat Types

# %%
kill.threat_level.value_counts()
# Out:
# attack          1462
# other            677
# undetermined     115
# Name: threat_level, dtype: int64

# %%
# Out:
# attack          1462
# other            677
# undetermined     115
# Name: threat_level, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(4, 4))
sns.countplot(x='threat_level', data=kill);

# %%
# with seaborn

# %% [markdown]
# ## 6: Plot number of Flee Types

# %%
kill.flee.value_counts()
# Out:
# Not fleeing    1528
# Car             360
# Foot            278
# Other            88
# Name: flee, dtype: int64

# %%
# Out:
# Not fleeing    1528
# Car             360
# Foot            278
# Other            88
# Name: flee, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(4, 4))
sns.countplot(x='flee', data=kill);

# %%
# with seaborn
